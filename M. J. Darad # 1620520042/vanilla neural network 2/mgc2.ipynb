# %%
# %matplotlib inline
import itertools
import numpy, scipy, matplotlib.pyplot as plt, pandas, librosa,sklearn
import config

from sklearn.neural_network import MLPClassifier

# %%
data_set=pandas.read_csv('data_set.csv',index_col=False)
GENRES=['METAL', 'CLASSICAL', 'HIPHOP', 'BLUES', 'POP', 'REGGAE']

number_of_rows,number_of_cols = data_set.shape
data_set[:5].style
# Out:
# <style  type="text/css" >
# </style><table id="T_62496514_2534_11ea_9740_00d8612ee2c4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >meanZCR</th>        <th class="col_heading level0 col1" >stdZCR</th>        <th class="col_heading level0 col2" >meanSpecCentroid</th>        <th class="col_heading level0 col3" >stdSpecCentroid</th>        <th class="col_heading level0 col4" >meanSpecContrast</th>        <th class="col_heading level0 col5" >stdSpecContrast</th>        <th class="col_heading level0 col6" >meanSpecBandwidth</th>        <th class="col_heading level0 col7" >stdSpecBandwidth</th>        <th class="col_heading level0 col8" >meanSpecRollof</th>        <th class="col_heading level0 col9" >stdSpecRollof</th>        <th class="col_heading level0 col10" >meanMFCC_1</th>        <th class="col_heading level0 col11" >stdMFCC_1</th>        <th class="col_heading level0 col12" >meanMFCC_2</th>        <th class="col_heading level0 col13" >stdMFCC_2</th>        <th class="col_heading level0 col14" >meanMFCC_3</th>        <th class="col_heading level0 col15" >stdMFCC_3</th>        <th class="col_heading level0 col16" >meanMFCC_4</th>        <th class="col_heading level0 col17" >stdMFCC_4</th>        <th class="col_heading level0 col18" >meanMFCC_5</th>        <th class="col_heading level0 col19" >stdMFCC_5</th>        <th class="col_heading level0 col20" >meanMFCC_6</th>        <th class="col_heading level0 col21" >stdMFCC_6</th>        <th class="col_heading level0 col22" >meanMFCC_7</th>        <th class="col_heading level0 col23" >stdMFCC_7</th>        <th class="col_heading level0 col24" >meanMFCC_8</th>        <th class="col_heading level0 col25" >stdMFCC_8</th>        <th class="col_heading level0 col26" >meanMFCC_9</th>        <th class="col_heading level0 col27" >stdMFCC_9</th>        <th class="col_heading level0 col28" >meanMFCC_10</th>        <th class="col_heading level0 col29" >stdMFCC_10</th>        <th class="col_heading level0 col30" >meanMFCC_11</th>        <th class="col_heading level0 col31" >stdMFCC_11</th>        <th class="col_heading level0 col32" >meanMFCC_12</th>        <th class="col_heading level0 col33" >stdMFCC_12</th>        <th class="col_heading level0 col34" >meanMFCC_13</th>        <th class="col_heading level0 col35" >stdMFCC_13</th>        <th class="col_heading level0 col36" >genre</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62496514_2534_11ea_9740_00d8612ee2c4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col0" class="data row0 col0" >-0.505871</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col1" class="data row0 col1" >-0.784343</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col2" class="data row0 col2" >-0.381408</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col3" class="data row0 col3" >-0.691147</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col4" class="data row0 col4" >-0.107291</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col5" class="data row0 col5" >0.349902</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col6" class="data row0 col6" >-0.18728</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col7" class="data row0 col7" >-0.572265</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col8" class="data row0 col8" >-0.236668</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col9" class="data row0 col9" >-0.455356</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col10" class="data row0 col10" >0.147821</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col11" class="data row0 col11" >-0.734165</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col12" class="data row0 col12" >-0.142672</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col13" class="data row0 col13" >-0.508729</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col14" class="data row0 col14" >0.268372</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col15" class="data row0 col15" >-0.543969</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col16" class="data row0 col16" >-0.127472</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col17" class="data row0 col17" >-0.543927</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col18" class="data row0 col18" >0.24025</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col19" class="data row0 col19" >-0.56626</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col20" class="data row0 col20" >-0.316155</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col21" class="data row0 col21" >-0.498744</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col22" class="data row0 col22" >0.455135</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col23" class="data row0 col23" >-0.220863</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col24" class="data row0 col24" >-0.0872071</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col25" class="data row0 col25" >-0.394531</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col26" class="data row0 col26" >0.0908564</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col27" class="data row0 col27" >-0.114378</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col28" class="data row0 col28" >-0.174782</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col29" class="data row0 col29" >-0.716931</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col30" class="data row0 col30" >0.379757</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col31" class="data row0 col31" >-0.826331</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col32" class="data row0 col32" >0.0651917</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col33" class="data row0 col33" >-0.802478</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col34" class="data row0 col34" >0.243325</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col35" class="data row0 col35" >-0.609704</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row0_col36" class="data row0 col36" >blues</td>
#             </tr>
#             <tr>
#                         <th id="T_62496514_2534_11ea_9740_00d8612ee2c4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col0" class="data row1 col0" >-0.789556</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col1" class="data row1 col1" >-0.726759</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col2" class="data row1 col2" >-0.559681</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col3" class="data row1 col3" >-0.463433</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col4" class="data row1 col4" >-0.214652</td>
#                         <td id="T_62496514_2534_11ea_9740_00d8612ee2c4row1_col5" class="data row1 col5" >0.274741</td>
#                         <td id="T_62496514_2534_11ea_9740_00d

# %%
from sklearn.model_selection import train_test_split

data_set_values=numpy.array(data_set)

train, test = train_test_split(data_set_values, test_size = 0.85,random_state=2,
                              stratify=data_set_values[:,number_of_cols-1])

train_x=train[:,:number_of_cols-1]
train_y=train[:,number_of_cols-1]

test_x=test[:,:number_of_cols-1]
test_y=test[:,number_of_cols-1]

print("Training data size: {}".format(train.shape))
print("Test data size: {}".format(test.shape))
# Out:
# Training data size: (150, 37)
# Test data size: (850, 37)

# %%
def confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = numpy.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot_cnf(model,dataset_x,dataset_y,GENRES):
    true_y=dataset_y
    true_x=dataset_x
    pred=model.predict(true_x)

    print("---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------\n")

    print("Real Test dataset labels: \n{}\n".format(true_y))
    print("Predicted Test dataset labels: \n{}".format(pred))

    cnf_matrix=sklearn.metrics.confusion_matrix(true_y,pred)
    plt.figure()
    a=confusion_matrix(cnf_matrix,classes=GENRES,title='Confusion matrix')

# %%
neural=MLPClassifier(max_iter=400,random_state=2,hidden_layer_sizes=[40,40])
neural.fit(train_x,train_y)
print("Training Score: {:.3f}".format(neural.score(train_x,train_y)))
print("Test score: {:.3f}".format(neural.score(test_x,test_y)))

plot_cnf(neural,test_x,test_y,GENRES)
# Out:
# C:\Users\JUNEJU\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training Score: 1.000
# Test score: 0.518
# ---------------PERFORMANCE ANALYSIS FOR THE MODEL----------------
#
# Real Test dataset labels:
# ['jazz' 'metal' 'reggae' 'hiphop' 'jazz' 'reggae' 'country' 'pop' 'metal'
#  'hiphop' 'hiphop' 'reggae' 'jazz' 'country' 'metal' 'reggae' 'classical'
#  'rock' 'reggae' 'rock' 'country' 'metal' 'pop' 'classical' 'jazz'
#  'classical' 'classical' 'disco' 'jazz' 'disco' 'hiphop' 'classical'
#  'rock' 'blues' 'metal' 'classical' 'jazz' 'disco' 'hiphop' 'jazz' 'pop'
#  'reggae' 'country' 'jazz' 'jazz' 'reggae' 'disco' 'reggae' 'metal'
#  'classical' 'reggae' 'pop' 'hiphop' 'rock' 'blues' 'hiphop' 'reggae'
#  'hiphop' 'hiphop' 'classical' 'reggae' 'country' 'reggae' 'rock' 'pop'
#  'pop' 'pop' 'jazz' 'classical' 'hiphop' 'reggae' 'disco' 'disco' 'reggae'
#  'country' 'metal' 'classical' 'metal' 'jazz' 'rock' 'blues' 'blues' 'pop'
#  'hiphop' 'pop' 'reggae' 'metal' 'jazz' 'metal' 'blues' 'classical'
#  'country' 'rock' 'disco' 'pop' 'rock' 'pop' 'classical' 'jazz' 'metal'
#  'classical' 'disco' 'rock' 'country' 'country' 'pop' 'reggae' 'reggae'
#  'hiphop' 'blues' 'reggae' 'disco' 'reggae' 'pop' 'classical' 'country'
#  'rock' 'blues' 'metal' 'pop' 'country' 'classical' 'country' 'disco'
#  'blues' 'metal' 'rock' 'country' 'blues' 'hiphop' 'blues' 'disco' 'pop'
#  'rock' 'country' 'pop' 'country' 'metal' 'jazz' 'rock' 'jazz' 'classical'
#  'metal' 'disco' 'reggae' 'rock' 'blues' 'jazz' 'jazz' 'metal' 'hiphop'
#  'rock' 'rock' 'blues' 'metal' 'blues' 'hiphop' 'pop' 'blues' 'hiphop'
#  'country' 'classical' 'classical' 'blues' 'blues' 'disco' 'hiphop' 'pop'
#  'hiphop' 'classical' 'rock' 'jazz' 'hiphop' 'pop' 'blues' 'classical'
#  'blues' 'jazz' 'disco' 'country' 'hiphop' 'jazz' 'pop' 'jazz' 'country'
#  'pop' 'hiphop' 'hiphop' 'reggae' 'reggae' 'classical' 'jazz' 'jazz'
#  'blues' 'disco' 'pop' 'reggae' 'classical' 'country' 'classical' 'pop'
#  'blues' 'country' 'disco' 'reggae' 'classical' 'metal' 'rock' 'jazz'
#  'classical' 'pop' 'pop' 'classical' 'reggae' 'blues' 'blues' 'reggae'
#  'jazz' 'rock' 'reggae' 'country' 'blues' 'metal' 'disco' 'pop' 'hiphop'
#  'classical' 'metal' 'disco' 'blues' 'rock' 'rock' 'reggae' 'metal'
#  'disco' 'rock' 'country' 'rock' 'country' 'pop' 'reggae' 'rock' 'metal'
#  'jazz' 'blues' 'classical' 'reggae' 'metal' 'classical' 'rock' 'pop'
#  'metal' 'reggae' 'jazz' 'classical' 'blues' 'country' 'disco' 'country'
#  'classical' 'hiphop' 'jazz' 'blues' 'country' 'metal' 'classical'
#  'classical' 'disco' 'country' 'jazz' 'disco' 'reggae' 'pop' 'metal'
#  'reggae' 'country' 'disco' 'country' 'classical' 'reggae' 'country' 'pop'
#  'reggae' 'country' 'pop' 'reggae' 'jazz' 'pop' 'classical' 'hiphop'
#  'jazz' 'blues' 'blues' 'blues' 'classical' 'reggae' 'blues' 'blues'
#  'hiphop' 'hiphop' 'rock' 'disco' 'pop' 'classical' 'classical' 'jazz'
#  'reggae' 'disco' 'country' 'disco' 'hiphop' 'disco' 'rock' 'pop'
#  'country' 'classical' 'jazz' 'pop' 'blues' 'reggae' 'blues' 'disco'
#  'classical' 'jazz' 'pop' 'hiphop' 'country' 'blues' 'hiphop' 'rock'
#  'country' 'rock' 'blues' 'blues' 'reggae' 'blues' 'blues' 'disco'
#  'reggae' 'classical' 'jazz' 'disco' 'disco' 'hiphop' 'disco' 'disco'
#  'hiphop' 'metal' 'hiphop' 'metal' 'reggae' 'pop' 'metal' 'jazz' 'disco'
#  'disco' 'classical' 'disco' 'jazz' 'classical' 'classical' 'pop' 'rock'
#  'hiphop' 'hiphop' 'disco' 'pop' 'rock' 'classical' 'classical' 'blues'
#  'metal' 'country' 'reggae' 'rock' 'classical' 'country' 'classical'
#  'reggae' 'hiphop' 'jazz' 'disco' 'country' 'blues' 'jazz' 'jazz' 'metal'
#  'pop' 'country' 'rock' 'jazz' 'metal' 'country' 'metal' 'rock' 'blues'
#  'country' 'blues' 'country' 'pop' 'country' 'pop' 'metal' 'blues' 'metal'
#  'jazz' 'country' 'country' 'hiphop' 'hiphop' 'classical' 'country' 'jazz'
#  'hiphop' 'rock' 'classical' 'rock' 'blues' 'jazz' 'rock' 'hiphop' 'pop'
#  'hiphop' 'pop' 'pop' 'jazz' 'pop' 'pop' 'disco' 'blues' 'metal' 'metal'
#  'classical' 'blues' 'jazz' 'classical' 'jazz' 'disco' 'metal' 'reggae'
#  'metal' 'classical' 'reggae' 'rock' 'hiphop' 'rock' 'reggae' 'rock'
#  'metal' 'pop' 'country' 'reggae' 'metal' 'hiphop' 'blues' 'jazz'
#  'classical' 'metal' 'metal' 'disco' 'disco' 'rock' 'jazz' 'rock' 'hiphop'
#  'classical' 'disco' 'metal' 'jazz' 'jazz' 'pop' 'disco' 'metal' 'rock'
#  'metal' 'reggae' 'country' 'rock' 'classical' 'hiphop' 'metal' 'rock'
#  'metal' 'disco' 'disco' 'blues' 'metal' 'hiphop' 'jazz' 'disco' 'metal'
#  'jazz' 'blues' 'country' 'disco' 'pop' 'blues' 'blues' 'hiphop' 'disco'
#  'pop' 'metal' 'hiphop' 'hiphop' 'country' 'reggae' 'rock' 'disco' 'disco'
#  'blues' 'reggae' 'reggae' 'reggae' 'jazz' 'country' 'jazz' 'blues'
#  'reggae' 'pop' 'disco' 'jazz' 'hiphop' 'hiphop' 'jazz' 'jazz' 'reggae'
#  'jazz' 'pop' 'disco' 'classical' 'hiphop' 'pop' 'jazz' 'jazz' 'metal'
#  'pop' 'rock' 'reggae' 'disco' 'reggae' 'rock' 'disco' 'country' 'country'
#  'country' 'disco' 'blues' 'country' 'disco' 'blues' 'rock' 'pop' 'rock'
#  'rock' 'blues' 'pop' 'hiphop' 'metal' 'reggae' 'classical' 'country'
#  'country' 'metal' 'blues' 'reggae' 'rock' 'classical' 'metal' 'hiphop'
#  'reggae' 'country' 'metal' 'hiphop' 'pop' 'classical' 'classical' 'disco'
#  'disco' 'hiphop' 'classical' 'disco' 'pop' 'country' 'pop' 'hiphop'
#  'rock' 'pop' 'metal' 'country' 'hiphop' 'country' 'blues' 'metal' 'jazz'
#  'jazz' 'metal' 'hiphop' 'rock' 'jazz' 'metal' 'reggae' 'jazz' 'rock'
#  'classical' 'reggae' 'jazz' 'rock' 'rock' 'country' 'country' 'hiphop'
#  'metal' 'pop' 'metal' 'pop' 'jazz' 'classical' 'reggae' 'country'
#  'country' 'metal' 'metal' 'jazz' 'country' 'rock' 'jazz' 'rock' 'metal'
#  'metal' 'hiphop' 'classical' 'reggae' 'metal' 'reggae' 'rock' 'rock'
#  'disco' 'metal' 'pop' 'jazz' 'classical' 'blues' 'country' 'reggae'
#  'disco' 'hiphop' 'metal' 'pop' 'reggae' 'blues' 'disco' 'disco' 'jazz'
#  'reggae' 'disco' 'reggae' 'classical' 'country' 'hiphop' 'disco'
#  'country' 'hiphop' 'jazz' 'reggae' 'pop' 'rock' 'blues' 'country' 'disco'
#  'classical' 'rock' 'hiphop' 'disco' 'blues' 'rock' 'blues' 'hiphop'
#  'rock' 'blues' 'reggae' 'disco' 'rock' 'classical' 'rock' 'jazz' 'blues'
#  'metal' 'rock' 'classical' 'rock' 'metal' 'hiphop' 'metal' 'blues'
#  'reggae' 'hiphop' 'hiphop' 'classical' 'hiphop' 'jazz' 'reggae' 'metal'
#  'metal' 'hiphop' 'jazz' 'country' 'reggae' 'pop' 'jazz' 'metal' 'disco'
#  'hiphop' 'disco' 'hiphop' 'hiphop' 'hiphop' 'disco' 'classical' 'rock'
#  'pop' 'metal' 'classical' 'pop' 'reggae' 'reggae' 'metal' 'rock' 'hiphop'
#  'country' 'blues' 'classical' 'pop' 'classical' 'metal' 'jazz' 'pop'
#  'blues' 'blues' 'jazz' 'disco' 'jazz' 'rock' 'pop' 'rock' 'metal'
#  'reggae' 'blues' 'disco' 'country' 'disco' 'blues' 'disco' 'rock'
#  'country' 'classical' 'blues' 'hiphop' 'country' 'pop' 'blues' 'jazz'
#  'blues' 'country' 'metal' 'hiphop' 'country' 'disco' 'country' 'jazz'
#  'rock' 'blues' 'hiphop' 'pop' 'rock' 'classical' 'rock' 'blues' 'pop'
#  'blues' 'pop' 'rock' 'disco' 'blues' 'rock' 'country' 'disco' 'classical'
#  'blues' 'hiphop' 'pop' 'country' 'reggae' 'metal' 'rock' 'reggae' 'blues'
#  'pop' 'jazz' 'rock' 'reggae' 'jazz' 'metal' 'reggae' 'country' 'country'
#  'country' 'pop' 'disco' 'hiphop' 'classical' 'classical' 'reggae' 'disco'
#  'blues' 'rock' 'jazz' 'reggae' 'country' 'blues' 'hiphop' 'classical'
#  'jazz' 'blues' 'rock' 'metal' 'hiphop' 'pop' 'rock' 'rock' 'hiphop'
#  'disco' 'disco' 'reggae' 'hiphop' 'pop' 'blues' 'classical' 'metal'
#  'classical' 'classical' 'disco' 'pop' 'country' 'metal' 'pop' 'reggae'
#  'disco' 'pop' 'pop' 'classical']
#
# Predicted Test dataset labels:
# ['jazz' 'metal' 'reggae' 'disco' 'rock' 'hiphop' 'country' 'pop' 'disco'
#  'hiphop' 'disco' 'hiphop' 'jazz' 'blues' 'metal' 'reggae' 'classical'
#  'blues' 'pop' 'blues' 'disco' 'metal' 'reggae' 'country' 'jazz'
#  'classical' 'classical' 'disco' 'blues' 'disco' 'hiphop' 'classical'
#  'jazz' 'metal' 'metal' 'classical' 'classical' 'rock' 'pop' 'blues'
#  'hiphop' 'reggae' 'country' 'jazz' 'jazz' 'pop' 'disco' 'hiphop' 'blues'
#  'classical' 'pop' 'pop' 'pop' 'disco' 'hiphop' 'hiphop' 'reggae' 'hiphop'
#  'reggae' 'classical' 'reggae' 'rock' 'reggae' 'disco' 'hiphop' 'pop'
#  'pop' 'jazz' 'classical' 'rock' 'reggae' 'disco' 'reggae' 'reggae'
#  'country' 'metal' 'classical' 'metal' 'jazz' 'rock' 'blues' 'blues'
#  'hiphop' 'reggae' 'pop' 'hiphop' 'metal' 'disco' 'hiphop' 'blues'
#  'classical' 'hiphop' 'reggae' 'disco' 'pop' 'metal' 'pop' 'classical'
#  'jazz' 'metal' 'classical' 'disco' 'rock' 'country' 'reggae' 'pop' 'rock'
#  'country' 'disco' 'jazz' 'reggae' 'pop' 'reggae' 'pop' 'classical' 'rock'
#  'disco' 'blues' 'metal' 'country' 'country' 'classical' 'country' 'disco'
#  'metal' 'hiphop' 'metal' 'country' 'blues' 'hiphop' 'metal' 'disco' 'pop'
#  'jazz' 'country' 'hiphop' 'pop' 'metal' 'jazz' 'metal' 'jazz' 'classical'
#  'metal' 'disco' 'reggae' 'disco' 'blues' 'blues' 'jazz' 'hiphop' 'pop'
#  'hiphop' 'metal' 'metal' 'hiphop' 'rock' 'blues' 'pop' 'metal' 'hiphop'
#  'disco' 'classical' 'classical' 'hiphop' 'blues' 'hiphop' 'hiphop' 'jazz'
#  'hiphop' 'classical' 'rock' 'jazz' 'pop' 'pop' 'reggae' 'classical'
#  'rock' 'blues' 'disco' 'pop' 'hiphop' 'jazz' 'pop' 'jazz' 'pop' 'pop'
#  'reggae' 'reggae' 'reggae' 'reggae' 'classical' 'disco' 'classical'
#  'reggae' 'disco' 'pop' 'metal' 'classical' 'pop' 'classical' 'pop'
#  'hiphop' 'jazz' 'disco' 'reggae' 'classical' 'jazz' 'pop' 'jazz' 'jazz'
#  'pop' 'jazz' 'classical' 'country' 'blues' 'classical' 'reggae' 'jazz'
#  'reggae' 'pop' 'country' 'blues' 'metal' 'jazz' 'pop' 'hiphop'
#  'classical' 'hiphop' 'pop' 'reggae' 'pop' 'blues' 'reggae' 'metal'
#  'hiphop' 'metal' 'blues' 'reggae' 'metal' 'reggae' 'hiphop' 'jazz'
#  'metal' 'rock' 'reggae' 'classical' 'pop' 'metal' 'classical' 'metal'
#  'pop' 'hiphop' 'country' 'classical' 'country' 'blues' 'country' 'disco'
#  'country' 'country' 'hiphop' 'blues' 'disco' 'disco' 'metal' 'classical'
#  'classical' 'rock' 'country' 'classical' 'reggae' 'reggae' 'pop' 'metal'
#  'country' 'country' 'pop' 'country' 'classical' 'reggae' 'rock' 'hiphop'
#  'disco' 'country' 'pop' 'reggae' 'rock' 'reggae' 'classical' 'pop' 'jazz'
#  'rock' 'blues' 'hiphop' 'blues' 'reggae' 'blues' 'rock' 'hiphop' 'disco'
#  'disco' 'disco' 'rock' 'country' 'classical' 'rock' 'reggae' 'hiphop'
#  'country' 'disco' 'reggae' 'disco' 'hiphop' 'pop' 'hiphop' 'jazz' 'jazz'
#  'rock' 'hiphop' 'reggae' 'metal' 'country' 'classical' 'classical'
#  'country' 'hiphop' 'jazz' 'blues' 'hiphop' 'country' 'country' 'jazz'
#  'blues' 'blues' 'pop' 'rock' 'blues' 'disco' 'hiphop' 'classical' 'jazz'
#  'rock' 'disco' 'reggae' 'hiphop' 'disco' 'reggae' 'metal' 'hiphop'
#  'metal' 'blues' 'pop' 'hiphop' 'jazz' 'disco' 'pop' 'classical' 'jazz'
#  'blues' 'classical' 'country' 'pop' 'metal' 'pop' 'pop' 'disco' 'pop'
#  'hiphop' 'classical' 'country' 'blues' 'metal' 'country' 'reggae' 'rock'
#  'classical' 'classical' 'classical' 'reggae' 'hiphop' 'jazz' 'disco'
#  'country' 'hiphop' 'jazz' 'classical' 'metal' 'pop' 'country' 'jazz'
#  'blues' 'metal' 'pop' 'metal' 'metal' 'blues' 'country' 'blues' 'country'
#  'reggae' 'blues' 'pop' 'metal' 'blues' 'disco' 'jazz' 'country' 'disco'
#  'hiphop' 'hiphop' 'classical' 'disco' 'classical' 'hiphop' 'rock'
#  'classical' 'rock' 'rock' 'jazz' 'classical' 'hiphop' 'pop' 'reggae'
#  'rock' 'pop' 'classical' 'pop' 'pop' 'disco' 'blues' 'metal' 'metal'
#  'classical' 'reggae' 'blues' 'jazz' 'blues' 'rock' 'hiphop' 'reggae'
#  'disco' 'classical' 'reggae' 'metal' 'hiphop' 'reggae' 'reggae' 'country'
#  'rock' 'pop' 'country' 'reggae' 'metal' 'disco' 'rock' 'classical'
#  'country' 'hiphop' 'metal' 'hiphop' 'reggae' 'rock' 'jazz' 'rock' 'metal'
#  'classical' 'hiphop' 'rock' 'jazz' 'jazz' 'disco' 'rock' 'metal' 'jazz'
#  'hiphop' 'hiphop' 'country' 'rock' 'classical' 'hiphop' 'hiphop' 'metal'
#  'metal' 'classical' 'jazz' 'rock' 'metal' 'hiphop' 'jazz' 'disco' 'metal'
#  'country' 'blues' 'rock' 'rock' 'hiphop' 'blues' 'blues' 'hiphop' 'metal'
#  'reggae' 'metal' 'pop' 'hiphop' 'country' 'reggae' 'reggae' 'disco'
#  'disco' 'reggae' 'reggae' 'reggae' 'pop' 'jazz' 'country' 'country'
#  'metal' 'disco' 'pop' 'pop' 'country' 'metal' 'hiphop' 'rock' 'blues'
#  'reggae' 'jazz' 'pop' 'disco' 'classical' 'disco' 'reggae' 'country'
#  'jazz' 'metal' 'pop' 'jazz' 'reggae' 'classical' 'rock' 'blues' 'pop'
#  'country' 'country' 'country' 'disco' 'reggae' 'country' 'disco' 'blues'
#  'reggae' 'pop' 'disco' 'disco' 'blues' 'pop' 'reggae' 'rock' 'reggae'
#  'classical' 'reggae' 'country' 'metal' 'hiphop' 'reggae' 'rock' 'country'
#  'jazz' 'reggae' 'blues' 'country' 'metal' 'hiphop' 'jazz' 'classical'
#  'country' 'rock' 'country' 'disco' 'classical' 'reggae' 'pop' 'reggae'
#  'pop' 'disco' 'classical' 'disco' 'rock' 'country' 'hiphop' 'country'
#  'rock' 'disco' 'jazz' 'jazz' 'metal' 'reggae' 'disco' 'jazz' 'metal'
#  'hiphop' 'country' 'rock' 'classical' 'hiphop' 'classical' 'rock' 'rock'
#  'reggae' 'reggae' 'reggae' 'metal' 'reggae' 'rock' 'pop' 'pop'
#  'classical' 'reggae' 'blues' 'pop' 'metal' 'rock' 'disco' 'pop' 'metal'
#  'classical' 'hiphop' 'metal' 'metal' 'reggae' 'classical' 'reggae'
#  'metal' 'pop' 'reggae' 'rock' 'disco' 'metal' 'disco' 'classical'
#  'classical' 'blues' 'rock' 'reggae' 'pop' 'hiphop' 'metal' 'pop'
#  'country' 'blues' 'hiphop' 'disco' 'jazz' 'blues' 'disco' 'country'
#  'classical' 'rock' 'metal' 'rock' 'country' 'hiphop' 'jazz' 'hiphop'
#  'pop' 'rock' 'country' 'classical' 'disco' 'jazz' 'disco' 'reggae'
#  'disco' 'metal' 'pop' 'blues' 'reggae' 'rock' 'blues' 'reggae' 'rock'
#  'rock' 'classical' 'country' 'jazz' 'metal' 'metal' 'reggae' 'classical'
#  'pop' 'disco' 'hiphop' 'metal' 'disco' 'hiphop' 'rock' 'metal'
#  'classical' 'reggae' 'jazz' 'reggae' 'metal' 'rock' 'disco' 'blues'
#  'rock' 'jazz' 'pop' 'blues' 'metal' 'disco' 'hiphop' 'pop' 'hiphop'
#  'blues' 'disco' 'disco' 'classical' 'reggae' 'pop' 'rock' 'jazz' 'pop'
#  'reggae' 'country' 'hiphop' 'rock' 'rock' 'country' 'blues' 'country'
#  'hiphop' 'jazz' 'metal' 'classical' 'pop' 'classical' 'blues' 'jazz'
#  'disco' 'country' 'disco' 'pop' 'rock' 'metal' 'reggae' 'metal' 'disco'
#  'jazz' 'reggae' 'jazz' 'disco' 'rock' 'country' 'classical' 'blues' 'pop'
#  'country' 'pop' 'hiphop' 'jazz' 'blues' 'country' 'metal' 'reggae'
#  'reggae' 'disco' 'rock' 'classical' 'country' 'blues' 'hiphop' 'reggae'
#  'jazz' 'classical' 'disco' 'metal' 'pop' 'disco' 'pop' 'jazz' 'rock'
#  'disco' 'pop' 'country' 'disco' 'classical' 'country' 'reggae' 'pop'
#  'disco' 'reggae' 'hiphop' 'disco' 'pop' 'rock' 'jazz' 'classical' 'pop'
#  'jazz' 'jazz' 'metal' 'reggae' 'rock' 'hiphop' 'reggae' 'pop' 'reggae'
#  'reggae' 'classical' 'classical' 'reggae' 'hiphop' 'reggae' 'metal'
#  'jazz' 'hiphop' 'country' 'blues' 'metal' 'reggae' 'classical' 'metal'
#  'disco' 'metal' 'hiphop' 'pop' 'pop' 'rock' 'reggae' 'disco' 'disco'
#  'reggae' 'reggae' 'pop' 'metal' 'classical' 'hiphop' 'jazz' 'classical'
#  'hiphop' 'pop' 'rock' 'jazz' 'country' 'disco' 'country' 'pop' 'disco'
#  'country']
